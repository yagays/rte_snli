# %%
import pandas as pd

# %%
train_df = pd.read_csv("../data/snli_1.0_train.txt", sep="\t", header=0)

# %%
train_df
# Out:
#            gold_label                             sentence1_binary_parse  \
# 0             neutral  ( ( ( A person ) ( on ( a horse ) ) ) ( ( jump...
# 1       contradiction  ( ( ( A person ) ( on ( a horse ) ) ) ( ( jump...
# 2          entailment  ( ( ( A person ) ( on ( a horse ) ) ) ( ( jump...
# 3             neutral  ( Children ( ( ( smiling and ) waving ) ( at c...
# 4          entailment  ( Children ( ( ( smiling and ) waving ) ( at c...
# 5       contradiction  ( Children ( ( ( smiling and ) waving ) ( at c...
# 6       contradiction  ( ( A boy ) ( ( is ( ( jumping ( on skateboard...
# 7          entailment  ( ( A boy ) ( ( is ( ( jumping ( on skateboard...
# 8             neutral  ( ( A boy ) ( ( is ( ( jumping ( on skateboard...
# 9             neutral  ( ( An ( older man ) ) ( ( ( sits ( with ( ( h...
# 10      contradiction  ( ( An ( older man ) ) ( ( ( sits ( with ( ( h...
# 11            neutral  ( ( An ( older man ) ) ( ( ( sits ( with ( ( h...
# ...

# %%
dev_df = pd.read_csv("../data/snli_1.0_dev.txt", sep="\t", header=0)

# %%
dev_df
# Out:
#          gold_label                             sentence1_binary_parse  \
# 0           neutral  ( ( Two women ) ( ( are ( embracing ( while ( ...
# 1        entailment  ( ( Two women ) ( ( are ( embracing ( while ( ...
# 2     contradiction  ( ( Two women ) ( ( are ( embracing ( while ( ...
# 3        entailment  ( ( ( Two ( young children ) ) ( in ( ( ( ( ( ...
# 4           neutral  ( ( ( Two ( young children ) ) ( in ( ( ( ( ( ...
# 5     contradiction  ( ( ( Two ( young children ) ) ( in ( ( ( ( ( ...
# 6     contradiction  ( ( A ( man selling ) ) ( ( donuts ( to ( a cu...
# 7           neutral  ( ( A ( man selling ) ) ( ( donuts ( to ( a cu...
# 8        entailment  ( ( A ( man selling ) ) ( ( donuts ( to ( a cu...
# 9        entailment  ( ( ( Two ( young boys ) ) ( of ( opposing tea...
# 10    contradiction  ( ( ( Two ( young boys ) ) ( of ( opposing tea...
# 11          neutral  ( ( ( Two ( young boys ) ) ( of ( opposing tea...
# ...

# %%
test_df = pd.read_csv("../data/snli_1.0_test.txt", sep="\t", header=0)

# %%
test_df
# Out:
#          gold_label                             sentence1_binary_parse  \
# 0           neutral  ( ( This ( church choir ) ) ( ( ( sings ( to (...
# 1        entailment  ( ( This ( church choir ) ) ( ( ( sings ( to (...
# 2     contradiction  ( ( This ( church choir ) ) ( ( ( sings ( to (...
# 3           neutral  ( ( ( A woman ) ( with ( ( ( ( ( a ( green hea...
# 4        entailment  ( ( ( A woman ) ( with ( ( ( ( ( a ( green hea...
# 5     contradiction  ( ( ( A woman ) ( with ( ( ( ( ( a ( green hea...
# 6        entailment  ( ( ( An ( old man ) ) ( with ( a package ) ) ...
# 7           neutral  ( ( ( An ( old man ) ) ( with ( a package ) ) ...
# 8     contradiction  ( ( ( An ( old man ) ) ( with ( a package ) ) ...
# 9           neutral  ( ( ( A statue ) ( at ( a museum ) ) ) ( ( tha...
# 10       entailment  ( ( ( A statue ) ( at ( a museum ) ) ) ( ( tha...
# 11    contradiction  ( ( ( A statue ) ( at ( a museum ) ) ) ( ( tha...
# ...

# %%
col = ["gold_label", "sentence1", "sentence2"]

# %%
train_df[col].to_csv("../data/train.tsv", sep="\t", index=None)
dev_df[col].to_csv("../data/dev.tsv", sep="\t", index=None)
test_df[col].to_csv("../data/test.tsv", sep="\t", index=None)
